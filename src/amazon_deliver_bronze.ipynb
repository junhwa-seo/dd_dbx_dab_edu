# %%
# Volume에 저장된 csv 파일을 읽어온다
bronze_df = spark.read.csv("/Volumes/training/sjh/volume/amazon_delivery.csv", header=True, inferSchema=True)

# %%
# bronze_df 출력
bronze_df.display()

# %%
# bronze_df를 'amazon_delivery_bronze' 테이블로 저장
bronze_df.write.mode("overwrite").saveAsTable("training.sjh.amazon_delivery_bronze")

# %%
# %sql
-- amazon_delivery_bronze 테이블 데이터 조회
select * from training.sjh.amazon_delivery_bronze
